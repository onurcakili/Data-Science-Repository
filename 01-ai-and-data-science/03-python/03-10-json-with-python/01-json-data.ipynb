# %% [markdown]
# # 1) JSON Data
#
# Kaynak: `D:\Projects\Data-Science-Repository\05_ai_and_datascience\3_python\3.9) JSON Data\1) JSON Data.docx`
#
# JSON Datalarıyla Çalışmak
#
# JSON datası, yapı itibariyle sözlüklere benzemektedir.
#
# Örnek

# %% [markdown]
# **Görsel 1**
#
# ![Görsel 1](attachment:image_001.png)

# %% [markdown]
# **Görsel 1 OCR kodu:**

# %%
8 import json
f"firstName" : "engin" , "lastName" : "demiroğ") '
adata
Y json.loads(data)

# %% [markdown]
# Bilgi: Loads, deyimi string olarak verilen bir datayı JSON Data tipine çevirmektedir.
#
# Dataları yazdırırken ise

# %% [markdown]
# **Görsel 2**
#
# ![Görsel 2](attachment:image_002.png)

# %% [markdown]
# **Görsel 2 OCR metni:**
#
# ```text
# 14 "firstName "J)
# 15
# ```
#
# Bir sözlükten gelen değeri JSON Data yapısına çevirmek..

# %% [markdown]
# **Görsel 3**
#
# ![Görsel 3](attachment:image_003.png)

# %% [markdown]
# **Görsel 3 OCR kodu:**

# %%
18customer -
19
20
21
22
"firstName” : "engin" ş
"email " : " engindemirog@gmail . com"
23customerJson z json.dumps(customer)
24 print(customer)

# %% [markdown]
# Bunu için ise Dumps, deyimi kullanılmaktadır.
