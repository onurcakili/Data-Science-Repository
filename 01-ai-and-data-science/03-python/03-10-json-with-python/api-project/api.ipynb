# %% [markdown]
# # api
#
# Kaynak: `D:\Projects\Data-Science-Repository\05_ai_and_datascience\3_python\3.9) JSON Data\api.project\api.py`

# %%
import json

with open("users.json") as users:
    data = json.load(users)
    print(data[0])
